# %% [markdown]
# ### This notebook is based on understanding of
# ## "Explainability in Graph Neural Networks"

# %% [markdown]
# #### Here, we are going to see GNNExplainer whihc is applying Shapley on the GNN

# %% [markdown]
# ### On the basis of Computation graph of the GNN i.e for a given node a computation graph can be created. This helps in explaining what nodes affect the given node.
# ![image.png](attachment:image.png)
